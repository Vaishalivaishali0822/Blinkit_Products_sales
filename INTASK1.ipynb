# %%
import pandas as pd

# %%
#import dataset
df = pd.read_csv("Blinkit _Productseda.csv")
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
#finding duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# Identify & Handle Missing Values

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# dtype: int64

# %%
#view informations of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
#describe the dataset
df.describe()
# Out:
#              index    sale_price  market_price        rating
# count  27555.00000  27555.000000  27555.000000  18929.000000
# mean   13778.00000    322.514808    382.056664      3.943410
# std     7954.58767    486.263116    581.730717      0.739063
# min        1.00000      2.450000      3.000000      1.000000
# 25%     6889.50000     95.000000    100.000000      3.700000
# 50%    13778.00000    190.000000    220.000000      4.100000
# 75%    20666.50000    359.000000    425.000000      4.300000
# max    27555.00000  12500.000000  12500.000000      5.000000

# %%
#view top 10 values
df.head(10)
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
#view 10lower values of the data 
df.tail(10)
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df['category'] = df['category'].str.upper()
#Convert to Uppercase(category column)

# %%
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        BEAUTY & HYGIENE              Hair Care  Sri Sri Ayurveda
# 1  KITCHEN, GARDEN & PETS  Storage & Accessories         Mastercook
# 2    CLEANING & HOUSEHOLD            Pooja Needs                Trm
# 3    CLEANING & HOUSEHOLD   Bins & Bathroom Ware             Nakoda
# 4        BEAUTY & HYGIENE       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df['product	'] = df['product'].str.title()
#Capitalize First Letter (Title Case)

# %%
df.head(3)
# Out:
#    index                                 product                category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg        BEAUTY & HYGIENE
# 1      2                   Water Bottle - Orange  KITCHEN, GARDEN & PETS
# 2      3          Brass Angle Deep - Plain, No.2    CLEANING & HOUSEHOLD
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
#
#                      type  rating                               product\t
# 0        Hair Oil & Serum     4.1  Garlic Oil - Vegetarian Capsule 500 Mg
# 1  Water & Fridge Bottles     2.3                   Water Bottle - Orange
# 2         Lamp & Lamp Oil     3.4          Brass Angle Deep - Plain, No.2

# %%
df['sale_price'].fillna(df['sale_price'].median(), inplace=True)
df['market_price'].fillna(df['market_price'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   product	      27554 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
#renameing the column heades
df.rename(columns={"rating":"RATING","sub_category":"SUB_CATRGORY"},inplace=True)
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              SUB_CATRGORY  \
# 0            BEAUTY & HYGIENE                 Hair Care
# 1      KITCHEN, GARDEN & PETS     Storage & Accessories
# ...

# %%
#ascending the data
df.sort_values(by="category",ascending=True)
# Out:
#        index                                            product  \
# 3619    3620               Baby Happy Wet Wipes - Silk & Cotton
# 8379    8380     Baby Miracle 400 ml Sipper Cup - 18 m+, Purple
# 26189  26190  Disposable Maternity & Nursing Breast Pads For...
# 4838    4839                                  Natural Baby Wash
# 6845    6846                           Gentle Baby Laundry Wash
# ...      ...                                                ...
# 13484  13485                                  Honey Ashwagandha
# 13479  13480                         Namkeen - Masala Groundnut
# 13477  13478                    22 Carat Bikaneri Papad - Small
# 13474  13475                       Quinoa Muesli - Honey & Nuts
# 14717  14718                                  Paratha - Malabar
#
#                      category              SUB_CATRGORY        brand  \
# 3619                BABY CARE           Diapers & Wipes        Bella
# ...

# %%
#count of the data
df["brand"].value_counts()
# Out:
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Wellastrate           1
# Clean & Fresh         1
# Lal                   1
# Glint                 1
# Baron De Bercy        1
# Name: brand, Length: 2313, dtype: int64

# %%
df["product"].sort_values(ascending=False)
# Out:
# 12128                                   pasta shell
# 1297      oriental-Instant Noodles - Tomato Flavour
# 7434     oriental Instant Noodles - Tom Yam Flavour
# 24247     oriental Instant Noodles - Masala Flavour
# 19284      oriental Instant Noodles - Curry Flavour
#                             ...
# 3072                    & Moms Bathing Soap - Tulsi
# 77                    & Moms Bathing Soap - Jasmine
# 25791                          & Moms - Sandal Soap
# 15870                          & Moms - Citrus Soap
# 14363                                           NaN
# Name: product, Length: 27555, dtype: object

# %%
#groupbying+sum
df.groupby("type")["product"].count()
# Out:
# type
# Adult Diapers                 40
# Aerated, Still, Sparkling     33
# Agarbatti, Incense Sticks     88
# Air Freshener                150
# Almonds                       13
#                             ...
# Wet Wipe, Pocket Tissues       9
# Whole Spices                 123
# Wine & Rice Vinegar            5
# Women's Deodorants           154
# Yogurt & Shrikhand            15
# Name: product, Length: 426, dtype: int64

# %%
#dropna 
df.dropna(subset=['SUB_CATRGORY'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   SUB_CATRGORY  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   RATING        18929 non-null  float64
#  9   product	      27554 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
#To string
df['index'] = df['index'].astype(str)
